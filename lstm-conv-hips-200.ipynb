# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/user1-all-h5/_hand.h5
# /kaggle/input/user1-all-h5/_hips.h5
# /kaggle/input/user1-all-h5/_torso.h5
# /kaggle/input/user1-all-h5/_bag.h5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
from sklearn import metrics
import h5py
import matplotlib.pyplot as plt
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout, SimpleRNN, GRU, LSTM, GlobalMaxPooling1D,GlobalMaxPooling2D,MaxPooling2D,BatchNormalization
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.losses import binary_crossentropy, categorical_crossentropy
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import itertools
from keras.utils.vis_utils import plot_model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
from sklearn import metrics
import h5py
import matplotlib.pyplot as plt
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Input,Conv1D, Conv2D, Dense, Flatten, Dropout, SimpleRNN, GRU, LSTM, GlobalMaxPooling1D,GlobalMaxPooling2D,MaxPooling2D,BatchNormalization
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.losses import binary_crossentropy, categorical_crossentropy
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import itertools
from keras.utils.vis_utils import plot_model
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# %%
class models():
    def __init__(self, path):
        self.path = path
        
        
    def read_h5(self):
        f = h5py.File(path, 'r')
        X = f.get('inputs')
        y = f.get('labels') 
        
        X = np.array(X)
        y = np.array(y)
        self.x_train, self.x_test, self.y_train, self.y_test = train_test_split(X, y, test_size=0.2, random_state = 1)
        print(self.x_train.shape,self.y_train.shape)
    def draw(self):
        f1 = plt.figure(1)
        plt.title('Loss')
        plt.plot(self.r.history['loss'], label = 'loss')
        plt.plot(self.r.history['val_loss'], label = 'val_loss')
        plt.legend()
        f1.show()
        
        f2 = plt.figure(2)
        plt.plot(self.r.history['accuracy'], label = 'accuracy')
        plt.plot(self.r.history['val_accuracy'], label = 'val_accuracy')
        plt.legend()
        f2.show()    
#     def cnn_model(self):
#         K = len(set(self.y_train))
# #         print(K)
        
#         print(self.x_train.shape,self.y_train.shape)
# #         Input_shape should be a 4dim vectors as stated in the keras doc:
#         self.x_train = np.expand_dims(self.x_train, -1)
#         self.x_test = np.expand_dims(self.x_test,-1)
#         print(self.x_train.shape,self.y_train.shape)
        
#         i = Input(shape=self.x_train[0].shape)
#         print(self.x_train[0].shape)
#         x = Conv2D(16, (3,3), strides = 2, activation = 'relu',padding='same',kernel_regularizer=regularizers.l2(0.0005))(i)
#         x = BatchNormalization()(x)
#         x = Dropout(0.2)(x)
#         x = Flatten()(x)    
#         x = Dropout(0.2)(x)
#         x = Dense(128,activation = 'relu')(x)
#         x = BatchNormalization()(x)
#         x = Dropout(0.2)(x)
#         x = Dense(K, activation = 'softmax')(x)       
#         self.model = Model(i,x)
#         self.model.compile(optimizer = Adam(learning_rate=0.0005),
#               loss = 'sparse_categorical_crossentropy',
#               metrics = ['accuracy'])
        
#         self.r = self.model.fit(self.x_train, self.y_train, validation_data = (self.x_test, self.y_test), epochs = 200, batch_size = 128 )
#         print(self.model.summary())
#         return self.r
    
    def cnn_model_2(self):
        K = len(set(self.y_train))
#         print(K)
        
        print(self.x_train.shape,self.y_train.shape)
#         Input_shape should be a 4dim vectors as stated in the keras doc:
#         self.x_train = np.expand_dims(self.x_train, -1)
#         self.x_test = np.expand_dims(self.x_test,-1)
        print(self.x_train.shape,self.y_train.shape)
        
        i = Input(shape=self.x_train[0].shape)
        print(self.x_train[0].shape)
        x = Conv1D(32, 5, strides = 1, activation = 'relu',padding='same',kernel_regularizer=regularizers.l2(0.0005))(i)
        #x = BatchNormalization()(x)
        x = MaxPooling2D(pool_size=(1,2), strides=(1,2))
        #x = Dropout(0.2)(x)
        #x = Flatten()(x)    
        #x = Dropout(0.2)(x)
        x = Conv1D(64, 3, strides = 1, activation = 'relu',padding='same',kernel_regularizer=regularizers.l2(0.0005))(i)
        #x = BatchNormalization()(x)
        x = MaxPooling2D(pool_size=(1,2), strides=(1,2))
        #x = Dropout(0.2)(x)
        #x = Flatten()(x)  
        #x = Dropout(0.2)(x)
        x = Conv1D(128, 3, strides = 1, activation = 'relu',padding='same',kernel_regularizer=regularizers.l2(0.0005))(i)
#         x=layers.Reshape((500, 23), input_shape=x.shape)
        x = layers.LSTM(64, return_sequences=True)(x)
        #x = Bidirectional(LSTM(64))(x)
        x = Flatten()(x)
        x = Dense(8, activation = 'softmax')(x)
        
        self.model = Model(i,x)
        self.model.compile(optimizer = Adam(learning_rate=0.0005),
              loss = 'sparse_categorical_crossentropy',
              metrics = ['accuracy'])
        
        self.r = self.model.fit(self.x_train, self.y_train, validation_data = (self.x_test, self.y_test), epochs = 200, batch_size = 128 )
        print(self.model.summary())
        return self.r
    
        
    def con_matrix(self):
        K = len(set(self.y_train))
        self.y_pred = self.model.predict(self.x_test).argmax(axis=1)
        cm = confusion_matrix(self.y_test,self.y_pred)
        self.plot_confusion_matrix(cm,list(range(K)))
    
    def plot_confusion_matrix(self, cm, classes, normalize = False, title='Confusion matrix', cmap=plt.cm.Blues):
        if normalize:
            cm = cm.astype('float') / cm.sum(axis=1)[:,np.newaxis]
            print("Normalized confusion matrix")
        else:
            print("Confusion matrix, without normalization")
        print(cm)
        f3 = plt.figure(3)
        plt.imshow(cm, interpolation='nearest', cmap=cmap)
        plt.title(title)
        plt.colorbar()
        tick_marks = np.arange(len(classes))
        plt.xticks(tick_marks, classes, rotation=45)
        plt.yticks(tick_marks, classes)
        
        fmt = '.2f' if normalize else 'd' 
        thresh = cm.max()/2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            plt.text(j, i, format(cm[i, j], fmt),
                     horizontalalignment = "center",
                     color = "white" if cm[i, j] > thresh else "black")
            plt.tight_layout()
            plt.ylabel('True label')
            plt.xlabel('predicted label')
            f3.show()

# %%
model_name = "cnn" 
path='/kaggle/input/user1-all-h5/_hips.h5'
motion = models(path)
motion.read_h5()
model=motion.cnn_model_2()
motion.draw()
motion.con_matrix()
# Out:
# (9716, 500, 22) (9716,)
# (9716, 500, 22) (9716,)
# (9716, 500, 22) (9716,)
# (500, 22)
# 2022-11-08 12:41:17.179202: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:41:17.180245: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:41:17.496528: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:41:17.497864: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:41:17.498638: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:41:17.499395: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:41:17.501615: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-08 12:41:17.759896: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:41:17.760746: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:41:17.761545: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:41:17.762342: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:41:17.763077: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:41:17.763778: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:41:22.533595: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:41:22.534524: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:41:22.535241: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:41:22.535993: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:41:22.536672: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:41:22.537320: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-11-08 12:41:22.542945: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 12:41:22.543608: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# 2022-11-08 12:41:24.269540: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 2022-11-08 12:41:27.859600: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 76/76 [==============================] - 19s 47ms/step - loss: 1.5702 - accuracy: 0.4511 - val_loss: 0.9935 - val_accuracy: 0.6412
# Epoch 2/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.8877 - accuracy: 0.6645 - val_loss: 0.7313 - val_accuracy: 0.7412
# Epoch 3/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.7118 - accuracy: 0.7374 - val_loss: 0.8044 - val_accuracy: 0.7333
# Epoch 4/200
# 76/76 [==============================] - 3s 41ms/step - loss: 0.6993 - accuracy: 0.7214 - val_loss: 0.7210 - val_accuracy: 0.7453
# Epoch 5/200
# 76/76 [==============================] - 3s 37ms/step - loss: 0.6381 - accuracy: 0.7681 - val_loss: 0.5564 - val_accuracy: 0.7844
# Epoch 6/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.5461 - accuracy: 0.7970 - val_loss: 0.5204 - val_accuracy: 0.8156
# Epoch 7/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.5484 - accuracy: 0.8004 - val_loss: 0.7203 - val_accuracy: 0.7218
# Epoch 8/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.5523 - accuracy: 0.8006 - val_loss: 0.5495 - val_accuracy: 0.8033
# Epoch 9/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.5374 - accuracy: 0.8122 - val_loss: 0.4536 - val_accuracy: 0.8280
# Epoch 10/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.4823 - accuracy: 0.8204 - val_loss: 0.4502 - val_accuracy: 0.8440
# Epoch 11/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.4744 - accuracy: 0.8321 - val_loss: 0.7099 - val_accuracy: 0.7547
# Epoch 12/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.4896 - accuracy: 0.8250 - val_loss: 0.4598 - val_accuracy: 0.8235
# Epoch 13/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.4576 - accuracy: 0.8374 - val_loss: 0.5134 - val_accuracy: 0.8214
# Epoch 14/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.4427 - accuracy: 0.8414 - val_loss: 0.4940 - val_accuracy: 0.8173
# Epoch 15/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.4054 - accuracy: 0.8536 - val_loss: 0.4583 - val_accuracy: 0.8309
# Epoch 16/200
# 76/76 [==============================] - 3s 40ms/step - loss: 0.4339 - accuracy: 0.8414 - val_loss: 0.4275 - val_accuracy: 0.8477
# Epoch 17/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.5081 - accuracy: 0.8186 - val_loss: 0.4680 - val_accuracy: 0.8412
# Epoch 18/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.4420 - accuracy: 0.8395 - val_loss: 0.4879 - val_accuracy: 0.8156
# Epoch 19/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.4209 - accuracy: 0.8503 - val_loss: 0.4953 - val_accuracy: 0.8189
# Epoch 20/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.5720 - accuracy: 0.7984 - val_loss: 0.5225 - val_accuracy: 0.8000
# Epoch 21/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.4407 - accuracy: 0.8407 - val_loss: 0.4189 - val_accuracy: 0.8556
# Epoch 22/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.3885 - accuracy: 0.8566 - val_loss: 0.4396 - val_accuracy: 0.8461
# Epoch 23/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.3687 - accuracy: 0.8630 - val_loss: 0.3707 - val_accuracy: 0.8638
# Epoch 24/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.3790 - accuracy: 0.8592 - val_loss: 0.4016 - val_accuracy: 0.8621
# Epoch 25/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.4119 - accuracy: 0.8502 - val_loss: 0.4156 - val_accuracy: 0.8514
# Epoch 26/200
# 76/76 [==============================] - 3s 37ms/step - loss: 0.3575 - accuracy: 0.8676 - val_loss: 0.3903 - val_accuracy: 0.8601
# Epoch 27/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.3615 - accuracy: 0.8701 - val_loss: 0.3864 - val_accuracy: 0.8687
# Epoch 28/200
# 76/76 [==============================] - 3s 40ms/step - loss: 0.3424 - accuracy: 0.8780 - val_loss: 0.3676 - val_accuracy: 0.8782
# Epoch 29/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.3664 - accuracy: 0.8662 - val_loss: 0.3960 - val_accuracy: 0.8683
# Epoch 30/200
# 76/76 [==============================] - 3s 37ms/step - loss: 0.3543 - accuracy: 0.8719 - val_loss: 0.4124 - val_accuracy: 0.8613
# Epoch 31/200
# 76/76 [==============================] - 2s 32ms/step - loss: 0.4016 - accuracy: 0.8552 - val_loss: 0.3855 - val_accuracy: 0.8782
# Epoch 32/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.3862 - accuracy: 0.8669 - val_loss: 0.3742 - val_accuracy: 0.8675
# Epoch 33/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.3516 - accuracy: 0.8742 - val_loss: 0.8773 - val_accuracy: 0.7988
# Epoch 34/200
# 76/76 [==============================] - 3s 37ms/step - loss: 0.7760 - accuracy: 0.7967 - val_loss: 0.4501 - val_accuracy: 0.8506
# Epoch 35/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.4131 - accuracy: 0.8563 - val_loss: 0.4427 - val_accuracy: 0.8366
# Epoch 36/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.4072 - accuracy: 0.8583 - val_loss: 0.3802 - val_accuracy: 0.8708
# Epoch 37/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.3425 - accuracy: 0.8749 - val_loss: 0.3704 - val_accuracy: 0.8597
# Epoch 38/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.3466 - accuracy: 0.8742 - val_loss: 0.3979 - val_accuracy: 0.8588
# Epoch 39/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.3443 - accuracy: 0.8743 - val_loss: 0.3646 - val_accuracy: 0.8695
# Epoch 40/200
# 76/76 [==============================] - 3s 41ms/step - loss: 0.3250 - accuracy: 0.8800 - val_loss: 0.4241 - val_accuracy: 0.8383
# Epoch 41/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.3420 - accuracy: 0.8764 - val_loss: 0.3856 - val_accuracy: 0.8671
# Epoch 42/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.3219 - accuracy: 0.8833 - val_loss: 0.3791 - val_accuracy: 0.8626
# Epoch 43/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.3256 - accuracy: 0.8844 - val_loss: 0.3528 - val_accuracy: 0.8753
# Epoch 44/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.3238 - accuracy: 0.8839 - val_loss: 0.3564 - val_accuracy: 0.8687
# Epoch 45/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.3150 - accuracy: 0.8853 - val_loss: 0.3580 - val_accuracy: 0.8704
# Epoch 46/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.3072 - accuracy: 0.8899 - val_loss: 0.4370 - val_accuracy: 0.8342
# Epoch 47/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.3012 - accuracy: 0.8953 - val_loss: 0.3528 - val_accuracy: 0.8856
# Epoch 48/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2897 - accuracy: 0.8989 - val_loss: 0.3679 - val_accuracy: 0.8745
# Epoch 49/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.3213 - accuracy: 0.8844 - val_loss: 0.3287 - val_accuracy: 0.8885
# Epoch 50/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2795 - accuracy: 0.9012 - val_loss: 0.3039 - val_accuracy: 0.8988
# Epoch 51/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.3079 - accuracy: 0.8884 - val_loss: 0.3499 - val_accuracy: 0.8856
# Epoch 52/200
# 76/76 [==============================] - 3s 38ms/step - loss: 0.3013 - accuracy: 0.8937 - val_loss: 0.3290 - val_accuracy: 0.8889
# Epoch 53/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.3215 - accuracy: 0.8885 - val_loss: 0.3350 - val_accuracy: 0.8761
# Epoch 54/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2735 - accuracy: 0.9046 - val_loss: 0.3250 - val_accuracy: 0.8951
# Epoch 55/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2848 - accuracy: 0.9006 - val_loss: 0.3664 - val_accuracy: 0.8790
# Epoch 56/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.3388 - accuracy: 0.8801 - val_loss: 0.4755 - val_accuracy: 0.8457
# Epoch 57/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2906 - accuracy: 0.8957 - val_loss: 0.4633 - val_accuracy: 0.8481
# Epoch 58/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.3301 - accuracy: 0.8862 - val_loss: 0.4590 - val_accuracy: 0.8551
# Epoch 59/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.3052 - accuracy: 0.8925 - val_loss: 0.2986 - val_accuracy: 0.8996
# Epoch 60/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2788 - accuracy: 0.9027 - val_loss: 0.3055 - val_accuracy: 0.8909
# Epoch 61/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.2617 - accuracy: 0.9074 - val_loss: 0.4025 - val_accuracy: 0.8704
# Epoch 62/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.2785 - accuracy: 0.9060 - val_loss: 0.5107 - val_accuracy: 0.8469
# Epoch 63/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2894 - accuracy: 0.9008 - val_loss: 0.3031 - val_accuracy: 0.8947
# Epoch 64/200
# 76/76 [==============================] - 3s 37ms/step - loss: 0.2660 - accuracy: 0.9078 - val_loss: 0.2810 - val_accuracy: 0.9115
# Epoch 65/200
# 76/76 [==============================] - 3s 41ms/step - loss: 0.2696 - accuracy: 0.9062 - val_loss: 0.3636 - val_accuracy: 0.8819
# Epoch 66/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2674 - accuracy: 0.9062 - val_loss: 0.3134 - val_accuracy: 0.8955
# Epoch 67/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2697 - accuracy: 0.9059 - val_loss: 0.4242 - val_accuracy: 0.8638
# Epoch 68/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2754 - accuracy: 0.9066 - val_loss: 0.3314 - val_accuracy: 0.8864
# Epoch 69/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2952 - accuracy: 0.8970 - val_loss: 0.3408 - val_accuracy: 0.8807
# Epoch 70/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.2708 - accuracy: 0.9081 - val_loss: 0.3443 - val_accuracy: 0.8934
# Epoch 71/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.3366 - accuracy: 0.8877 - val_loss: 0.3628 - val_accuracy: 0.8774
# Epoch 72/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2605 - accuracy: 0.9107 - val_loss: 0.3837 - val_accuracy: 0.8753
# Epoch 73/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2971 - accuracy: 0.9007 - val_loss: 0.3255 - val_accuracy: 0.9053
# Epoch 74/200
# 76/76 [==============================] - 3s 37ms/step - loss: 0.2664 - accuracy: 0.9082 - val_loss: 0.2950 - val_accuracy: 0.9115
# Epoch 75/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.3350 - accuracy: 0.8897 - val_loss: 0.3890 - val_accuracy: 0.8708
# Epoch 76/200
# 76/76 [==============================] - 3s 39ms/step - loss: 0.2740 - accuracy: 0.9043 - val_loss: 0.3471 - val_accuracy: 0.8979
# Epoch 77/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.2677 - accuracy: 0.9059 - val_loss: 0.3457 - val_accuracy: 0.8914
# Epoch 78/200
# 76/76 [==============================] - 3s 37ms/step - loss: 0.2655 - accuracy: 0.9070 - val_loss: 0.3176 - val_accuracy: 0.9053
# Epoch 79/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.2837 - accuracy: 0.9036 - val_loss: 0.3255 - val_accuracy: 0.8996
# Epoch 80/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2492 - accuracy: 0.9155 - val_loss: 0.4137 - val_accuracy: 0.8782
# Epoch 81/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2943 - accuracy: 0.8974 - val_loss: 0.3521 - val_accuracy: 0.8823
# Epoch 82/200
# 76/76 [==============================] - 3s 37ms/step - loss: 0.2557 - accuracy: 0.9153 - val_loss: 0.3795 - val_accuracy: 0.8893
# Epoch 83/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.3306 - accuracy: 0.8879 - val_loss: 0.4781 - val_accuracy: 0.8444
# Epoch 84/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2917 - accuracy: 0.8989 - val_loss: 0.3106 - val_accuracy: 0.8992
# Epoch 85/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2651 - accuracy: 0.9128 - val_loss: 0.3626 - val_accuracy: 0.8704
# Epoch 86/200
# 76/76 [==============================] - 3s 37ms/step - loss: 0.2980 - accuracy: 0.9005 - val_loss: 0.4194 - val_accuracy: 0.8691
# Epoch 87/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2681 - accuracy: 0.9119 - val_loss: 0.3035 - val_accuracy: 0.9049
# Epoch 88/200
# 76/76 [==============================] - 3s 40ms/step - loss: 0.2730 - accuracy: 0.9072 - val_loss: 0.2998 - val_accuracy: 0.8930
# Epoch 89/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2174 - accuracy: 0.9265 - val_loss: 0.2960 - val_accuracy: 0.9082
# Epoch 90/200
# 76/76 [==============================] - 3s 37ms/step - loss: 0.2641 - accuracy: 0.9134 - val_loss: 0.3347 - val_accuracy: 0.8971
# Epoch 91/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2336 - accuracy: 0.9226 - val_loss: 0.5302 - val_accuracy: 0.8716
# Epoch 92/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2730 - accuracy: 0.9088 - val_loss: 0.3456 - val_accuracy: 0.8926
# Epoch 93/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2619 - accuracy: 0.9139 - val_loss: 0.2922 - val_accuracy: 0.9066
# Epoch 94/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2578 - accuracy: 0.9158 - val_loss: 0.3062 - val_accuracy: 0.8992
# Epoch 95/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.2548 - accuracy: 0.9150 - val_loss: 0.3434 - val_accuracy: 0.8901
# Epoch 96/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2686 - accuracy: 0.9093 - val_loss: 0.2928 - val_accuracy: 0.8992
# Epoch 97/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2397 - accuracy: 0.9185 - val_loss: 0.3133 - val_accuracy: 0.9021
# Epoch 98/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2920 - accuracy: 0.9025 - val_loss: 0.3516 - val_accuracy: 0.8926
# Epoch 99/200
# 76/76 [==============================] - 3s 37ms/step - loss: 0.3286 - accuracy: 0.8879 - val_loss: 0.4031 - val_accuracy: 0.8835
# Epoch 100/200
# 76/76 [==============================] - 3s 41ms/step - loss: 0.2772 - accuracy: 0.9091 - val_loss: 0.3823 - val_accuracy: 0.8737
# Epoch 101/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2924 - accuracy: 0.9081 - val_loss: 0.3580 - val_accuracy: 0.8955
# Epoch 102/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2666 - accuracy: 0.9068 - val_loss: 0.3776 - val_accuracy: 0.8844
# Epoch 103/200
# 76/76 [==============================] - 3s 37ms/step - loss: 0.2918 - accuracy: 0.9056 - val_loss: 0.3029 - val_accuracy: 0.9119
# Epoch 104/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2820 - accuracy: 0.9066 - val_loss: 0.3779 - val_accuracy: 0.8761
# Epoch 105/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2552 - accuracy: 0.9175 - val_loss: 0.3340 - val_accuracy: 0.8967
# Epoch 106/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.2933 - accuracy: 0.9075 - val_loss: 0.3636 - val_accuracy: 0.8918
# Epoch 107/200
# 76/76 [==============================] - 3s 38ms/step - loss: 0.2587 - accuracy: 0.9112 - val_loss: 0.3016 - val_accuracy: 0.9041
# Epoch 108/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2531 - accuracy: 0.9193 - val_loss: 0.3033 - val_accuracy: 0.9091
# Epoch 109/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2765 - accuracy: 0.9098 - val_loss: 0.3656 - val_accuracy: 0.8856
# Epoch 110/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2854 - accuracy: 0.9092 - val_loss: 0.3566 - val_accuracy: 0.8971
# Epoch 111/200
# 76/76 [==============================] - 3s 38ms/step - loss: 0.3178 - accuracy: 0.8976 - val_loss: 0.3364 - val_accuracy: 0.8897
# Epoch 112/200
# 76/76 [==============================] - 3s 40ms/step - loss: 0.2662 - accuracy: 0.9133 - val_loss: 0.3211 - val_accuracy: 0.9012
# Epoch 113/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2711 - accuracy: 0.9079 - val_loss: 0.4875 - val_accuracy: 0.8724
# Epoch 114/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.3437 - accuracy: 0.8887 - val_loss: 0.3549 - val_accuracy: 0.8877
# Epoch 115/200
# 76/76 [==============================] - 3s 38ms/step - loss: 0.2884 - accuracy: 0.9031 - val_loss: 0.4004 - val_accuracy: 0.8634
# Epoch 116/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2931 - accuracy: 0.9045 - val_loss: 0.3362 - val_accuracy: 0.8996
# Epoch 117/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2573 - accuracy: 0.9154 - val_loss: 0.4229 - val_accuracy: 0.8646
# Epoch 118/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2367 - accuracy: 0.9195 - val_loss: 0.3243 - val_accuracy: 0.9025
# Epoch 119/200
# 76/76 [==============================] - 3s 38ms/step - loss: 0.2574 - accuracy: 0.9180 - val_loss: 0.4096 - val_accuracy: 0.8819
# Epoch 120/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.5631 - accuracy: 0.8619 - val_loss: 0.3918 - val_accuracy: 0.8864
# Epoch 121/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2539 - accuracy: 0.9178 - val_loss: 0.3267 - val_accuracy: 0.9045
# Epoch 122/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2489 - accuracy: 0.9178 - val_loss: 0.3663 - val_accuracy: 0.8971
# Epoch 123/200
# 76/76 [==============================] - 3s 39ms/step - loss: 0.2306 - accuracy: 0.9301 - val_loss: 0.3147 - val_accuracy: 0.9074
# Epoch 124/200
# 76/76 [==============================] - 3s 38ms/step - loss: 0.2296 - accuracy: 0.9260 - val_loss: 0.2949 - val_accuracy: 0.9156
# Epoch 125/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2149 - accuracy: 0.9311 - val_loss: 0.3165 - val_accuracy: 0.9119
# Epoch 126/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2292 - accuracy: 0.9252 - val_loss: 0.3453 - val_accuracy: 0.8942
# Epoch 127/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.2555 - accuracy: 0.9159 - val_loss: 0.3254 - val_accuracy: 0.8992
# Epoch 128/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.2220 - accuracy: 0.9255 - val_loss: 0.2821 - val_accuracy: 0.9222
# Epoch 129/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2177 - accuracy: 0.9277 - val_loss: 0.3965 - val_accuracy: 0.8831
# Epoch 130/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.4654 - accuracy: 0.8840 - val_loss: 1.0409 - val_accuracy: 0.6807
# Epoch 131/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.6040 - accuracy: 0.7929 - val_loss: 0.4909 - val_accuracy: 0.8432
# Epoch 132/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.4899 - accuracy: 0.8228 - val_loss: 0.4612 - val_accuracy: 0.8461
# Epoch 133/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.4017 - accuracy: 0.8588 - val_loss: 0.4482 - val_accuracy: 0.8461
# Epoch 134/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.4137 - accuracy: 0.8476 - val_loss: 0.4423 - val_accuracy: 0.8469
# Epoch 135/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.3599 - accuracy: 0.8713 - val_loss: 0.4569 - val_accuracy: 0.8379
# Epoch 136/200
# 76/76 [==============================] - 3s 42ms/step - loss: 0.3281 - accuracy: 0.8776 - val_loss: 0.4156 - val_accuracy: 0.8399
# Epoch 137/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.3712 - accuracy: 0.8648 - val_loss: 0.5574 - val_accuracy: 0.8251
# Epoch 138/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.3729 - accuracy: 0.8642 - val_loss: 0.4006 - val_accuracy: 0.8551
# Epoch 139/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.3622 - accuracy: 0.8703 - val_loss: 0.4304 - val_accuracy: 0.8613
# Epoch 140/200
# 76/76 [==============================] - 3s 38ms/step - loss: 0.3366 - accuracy: 0.8764 - val_loss: 0.3978 - val_accuracy: 0.8671
# Epoch 141/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.3419 - accuracy: 0.8749 - val_loss: 0.5458 - val_accuracy: 0.8288
# Epoch 142/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.3683 - accuracy: 0.8691 - val_loss: 0.3861 - val_accuracy: 0.8654
# Epoch 143/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.3120 - accuracy: 0.8901 - val_loss: 0.4262 - val_accuracy: 0.8358
# Epoch 144/200
# 76/76 [==============================] - 3s 37ms/step - loss: 0.3104 - accuracy: 0.8941 - val_loss: 0.4178 - val_accuracy: 0.8761
# Epoch 145/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.3107 - accuracy: 0.8895 - val_loss: 0.3949 - val_accuracy: 0.8646
# Epoch 146/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2841 - accuracy: 0.9042 - val_loss: 0.3605 - val_accuracy: 0.8827
# Epoch 147/200
# 76/76 [==============================] - 3s 37ms/step - loss: 0.2982 - accuracy: 0.8939 - val_loss: 0.3911 - val_accuracy: 0.8728
# Epoch 148/200
# 76/76 [==============================] - 3s 40ms/step - loss: 0.2926 - accuracy: 0.8975 - val_loss: 0.3663 - val_accuracy: 0.8761
# Epoch 149/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2934 - accuracy: 0.8981 - val_loss: 0.3352 - val_accuracy: 0.9029
# Epoch 150/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.3196 - accuracy: 0.8885 - val_loss: 0.3770 - val_accuracy: 0.8827
# Epoch 151/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2879 - accuracy: 0.9015 - val_loss: 0.3269 - val_accuracy: 0.8868
# Epoch 152/200
# 76/76 [==============================] - 3s 37ms/step - loss: 0.3203 - accuracy: 0.8881 - val_loss: 0.3751 - val_accuracy: 0.8955
# Epoch 153/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.3067 - accuracy: 0.8930 - val_loss: 0.4447 - val_accuracy: 0.8560
# Epoch 154/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.3273 - accuracy: 0.8865 - val_loss: 0.3831 - val_accuracy: 0.8724
# Epoch 155/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.3023 - accuracy: 0.8951 - val_loss: 0.3390 - val_accuracy: 0.8868
# Epoch 156/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.2945 - accuracy: 0.8959 - val_loss: 0.3569 - val_accuracy: 0.8889
# Epoch 157/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.3087 - accuracy: 0.8913 - val_loss: 0.4236 - val_accuracy: 0.8613
# Epoch 158/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2944 - accuracy: 0.8999 - val_loss: 0.3783 - val_accuracy: 0.8617
# Epoch 159/200
# 76/76 [==============================] - 3s 40ms/step - loss: 0.2906 - accuracy: 0.9006 - val_loss: 0.3600 - val_accuracy: 0.8914
# Epoch 160/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.2784 - accuracy: 0.9052 - val_loss: 0.3488 - val_accuracy: 0.8872
# Epoch 161/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2926 - accuracy: 0.9001 - val_loss: 0.3728 - val_accuracy: 0.8823
# Epoch 162/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.3352 - accuracy: 0.8890 - val_loss: 0.3852 - val_accuracy: 0.8798
# Epoch 163/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2828 - accuracy: 0.9049 - val_loss: 0.3396 - val_accuracy: 0.8918
# Epoch 164/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2655 - accuracy: 0.9084 - val_loss: 0.4035 - val_accuracy: 0.8708
# Epoch 165/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.2760 - accuracy: 0.9020 - val_loss: 0.3480 - val_accuracy: 0.8955
# Epoch 166/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2912 - accuracy: 0.9022 - val_loss: 0.3620 - val_accuracy: 0.8877
# Epoch 167/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2684 - accuracy: 0.9059 - val_loss: 0.3433 - val_accuracy: 0.8889
# Epoch 168/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2459 - accuracy: 0.9158 - val_loss: 0.3546 - val_accuracy: 0.8942
# Epoch 169/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.2501 - accuracy: 0.9151 - val_loss: 0.3308 - val_accuracy: 0.8955
# Epoch 170/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2430 - accuracy: 0.9184 - val_loss: 0.2951 - val_accuracy: 0.9128
# Epoch 171/200
# 76/76 [==============================] - 3s 40ms/step - loss: 0.3013 - accuracy: 0.9007 - val_loss: 0.3429 - val_accuracy: 0.8905
# Epoch 172/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2846 - accuracy: 0.9012 - val_loss: 0.3774 - val_accuracy: 0.8811
# Epoch 173/200
# 76/76 [==============================] - 3s 37ms/step - loss: 0.2808 - accuracy: 0.9054 - val_loss: 0.6057 - val_accuracy: 0.8058
# Epoch 174/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.3421 - accuracy: 0.8886 - val_loss: 0.4294 - val_accuracy: 0.8597
# Epoch 175/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2686 - accuracy: 0.9038 - val_loss: 0.3479 - val_accuracy: 0.9008
# Epoch 176/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2613 - accuracy: 0.9086 - val_loss: 0.3909 - val_accuracy: 0.8774
# Epoch 177/200
# 76/76 [==============================] - 3s 37ms/step - loss: 0.2371 - accuracy: 0.9211 - val_loss: 0.3336 - val_accuracy: 0.8889
# Epoch 178/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2656 - accuracy: 0.9110 - val_loss: 0.3303 - val_accuracy: 0.8909
# Epoch 179/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2474 - accuracy: 0.9182 - val_loss: 0.4660 - val_accuracy: 0.8634
# Epoch 180/200
# 76/76 [==============================] - 2s 33ms/step - loss: 0.2734 - accuracy: 0.9061 - val_loss: 0.3172 - val_accuracy: 0.9058
# Epoch 181/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.2381 - accuracy: 0.9231 - val_loss: 0.3865 - val_accuracy: 0.8708
# Epoch 182/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2564 - accuracy: 0.9118 - val_loss: 0.3436 - val_accuracy: 0.8840
# Epoch 183/200
# 76/76 [==============================] - 3s 40ms/step - loss: 0.2429 - accuracy: 0.9206 - val_loss: 0.3055 - val_accuracy: 0.9016
# Epoch 184/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2239 - accuracy: 0.9228 - val_loss: 0.2983 - val_accuracy: 0.9111
# Epoch 185/200
# 76/76 [==============================] - 3s 37ms/step - loss: 0.2212 - accuracy: 0.9284 - val_loss: 0.3182 - val_accuracy: 0.9029
# Epoch 186/200
# 76/76 [==============================] - 3s 35ms/step - loss: 0.2699 - accuracy: 0.9107 - val_loss: 0.3359 - val_accuracy: 0.9021
# Epoch 187/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2286 - accuracy: 0.9241 - val_loss: 0.3340 - val_accuracy: 0.9074
# Epoch 188/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2126 - accuracy: 0.9307 - val_loss: 0.3478 - val_accuracy: 0.9115
# Epoch 189/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2703 - accuracy: 0.9085 - val_loss: 0.3308 - val_accuracy: 0.9004
# Epoch 190/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.2593 - accuracy: 0.9133 - val_loss: 0.4272 - val_accuracy: 0.8712
# Epoch 191/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2502 - accuracy: 0.9188 - val_loss: 0.3148 - val_accuracy: 0.9025
# Epoch 192/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2293 - accuracy: 0.9222 - val_loss: 0.3105 - val_accuracy: 0.9037
# Epoch 193/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2887 - accuracy: 0.9079 - val_loss: 0.3762 - val_accuracy: 0.8749
# Epoch 194/200
# 76/76 [==============================] - 3s 36ms/step - loss: 0.2532 - accuracy: 0.9099 - val_loss: 0.2748 - val_accuracy: 0.9198
# Epoch 195/200
# 76/76 [==============================] - 3s 40ms/step - loss: 0.2177 - accuracy: 0.9307 - val_loss: 0.2977 - val_accuracy: 0.9144
# Epoch 196/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2385 - accuracy: 0.9191 - val_loss: 0.3688 - val_accuracy: 0.8848
# Epoch 197/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.2338 - accuracy: 0.9206 - val_loss: 0.3356 - val_accuracy: 0.9000
# Epoch 198/200
# 76/76 [==============================] - 3s 37ms/step - loss: 0.2027 - accuracy: 0.9332 - val_loss: 0.3317 - val_accuracy: 0.8996
# Epoch 199/200
# 76/76 [==============================] - 3s 34ms/step - loss: 0.2037 - accuracy: 0.9332 - val_loss: 0.2884 - val_accuracy: 0.9132
# Epoch 200/200
# 76/76 [==============================] - 3s 33ms/step - loss: 0.1975 - accuracy: 0.9361 - val_loss: 0.2819 - val_accuracy: 0.9144
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 500, 22)]         0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 500, 128)          8576
# _________________________________________________________________
# lstm (LSTM)                  (None, 500, 64)           49408
# _________________________________________________________________
# flatten (Flatten)            (None, 32000)             0
# _________________________________________________________________
# dense (Dense)                (None, 8)                 256008
# =================================================================
# Total params: 313,992
# Trainable params: 313,992
# Non-trainable params: 0
# _________________________________________________________________
# None
# Confusion matrix, without normalization
# [[308   3   0   0   2   0   0  59]
#  [ 10 277   0   0  17   1   8   2]
#  [  2   0 291   0   6   0   4   0]
#  [  0   0   2  41   0   0   0   0]
#  [  2   0   8   0 189   0   6   3]
#  [  0   0   0   0   0 406  21   0]
#  [  0   0   2   0   1   6 404   0]
#  [ 40   0   1   0   2   0   0 306]]
