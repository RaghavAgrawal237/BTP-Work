# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/user1-all-h5/_hand.h5
# /kaggle/input/user1-all-h5/_hips.h5
# /kaggle/input/user1-all-h5/_torso.h5
# /kaggle/input/user1-all-h5/_bag.h5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
from sklearn import metrics
import h5py
import matplotlib.pyplot as plt
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout, SimpleRNN, GRU, LSTM, GlobalMaxPooling1D,GlobalMaxPooling2D,MaxPooling2D,BatchNormalization
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.losses import binary_crossentropy, categorical_crossentropy
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import itertools
from keras.utils.vis_utils import plot_model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
from sklearn import metrics
import h5py
import matplotlib.pyplot as plt
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Bidirectional,Input,Conv1D, Conv2D, Dense, Flatten, Dropout, SimpleRNN, GRU, LSTM, GlobalMaxPooling1D,GlobalMaxPooling2D,MaxPooling2D,BatchNormalization
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.losses import binary_crossentropy, categorical_crossentropy
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import itertools
from keras.utils.vis_utils import plot_model
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# %%
class models():
    def __init__(self, path):
        self.path = path
        
        
    def read_h5(self):
        f = h5py.File(path, 'r')
        X = f.get('inputs')
        y = f.get('labels') 
        
        X = np.array(X)
        y = np.array(y)
        self.x_train, self.x_test, self.y_train, self.y_test = train_test_split(X, y, test_size=0.2, random_state = 1)
        print(self.x_train.shape,self.y_train.shape)
    def draw(self):
        f1 = plt.figure(1)
        plt.title('Loss')
        plt.plot(self.r.history['loss'], label = 'loss')
        plt.plot(self.r.history['val_loss'], label = 'val_loss')
        plt.legend()
        f1.show()
        
        f2 = plt.figure(2)
        plt.plot(self.r.history['accuracy'], label = 'accuracy')
        plt.plot(self.r.history['val_accuracy'], label = 'val_accuracy')
        plt.legend()
        f2.show()    
#     def cnn_model(self):
#         K = len(set(self.y_train))
# #         print(K)
        
#         print(self.x_train.shape,self.y_train.shape)
# #         Input_shape should be a 4dim vectors as stated in the keras doc:
#         self.x_train = np.expand_dims(self.x_train, -1)
#         self.x_test = np.expand_dims(self.x_test,-1)
#         print(self.x_train.shape,self.y_train.shape)
        
#         i = Input(shape=self.x_train[0].shape)
#         print(self.x_train[0].shape)
#         x = Conv2D(16, (3,3), strides = 2, activation = 'relu',padding='same',kernel_regularizer=regularizers.l2(0.0005))(i)
#         x = BatchNormalization()(x)
#         x = Dropout(0.2)(x)
#         x = Flatten()(x)    
#         x = Dropout(0.2)(x)
#         x = Dense(128,activation = 'relu')(x)
#         x = BatchNormalization()(x)
#         x = Dropout(0.2)(x)
#         x = Dense(K, activation = 'softmax')(x)       
#         self.model = Model(i,x)
#         self.model.compile(optimizer = Adam(learning_rate=0.0005),
#               loss = 'sparse_categorical_crossentropy',
#               metrics = ['accuracy'])
        
#         self.r = self.model.fit(self.x_train, self.y_train, validation_data = (self.x_test, self.y_test), epochs = 200, batch_size = 128 )
#         print(self.model.summary())
#         return self.r
    
    def cnn_model_2(self):
        K = len(set(self.y_train))
#         print(K)
        
        print(self.x_train.shape,self.y_train.shape)
#         Input_shape should be a 4dim vectors as stated in the keras doc:
#         self.x_train = np.expand_dims(self.x_train, -1)
#         self.x_test = np.expand_dims(self.x_test,-1)
        print(self.x_train.shape,self.y_train.shape)
        
        i = Input(shape=self.x_train[0].shape)
        print(self.x_train[0].shape)
        x = Conv1D(32, 5, strides = 1, activation = 'relu',padding='same',kernel_regularizer=regularizers.l2(0.0005))(i)
        #x = BatchNormalization()(x)
        x = MaxPooling2D(pool_size=(1,2), strides=(1,2))
        #x = Dropout(0.2)(x)
        #x = Flatten()(x)    
        #x = Dropout(0.2)(x)
        x = Conv1D(64, 3, strides = 1, activation = 'relu',padding='same',kernel_regularizer=regularizers.l2(0.0005))(i)
        #x = BatchNormalization()(x)
        x = MaxPooling2D(pool_size=(1,2), strides=(1,2))
        #x = Dropout(0.2)(x)
        #x = Flatten()(x)  
        #x = Dropout(0.2)(x)
        x = Conv1D(128, 3, strides = 1, activation = 'relu',padding='same',kernel_regularizer=regularizers.l2(0.0005))(i)
#         x=layers.Reshape((500, 23), input_shape=x.shape)
        x = layers.LSTM(64, return_sequences=True)(x)
        #x = Bidirectional(LSTM(64))(x)
        x = Flatten()(x)
        x = Dense(8, activation = 'softmax')(x)
        
        self.model = Model(i,x)
        self.model.compile(optimizer = Adam(learning_rate=0.0005),
              loss = 'sparse_categorical_crossentropy',
              metrics = ['accuracy'])
        
        self.r = self.model.fit(self.x_train, self.y_train, validation_data = (self.x_test, self.y_test), epochs = 200, batch_size = 128 )
        print(self.model.summary())
        return self.r
    
        
    def con_matrix(self):
        K = len(set(self.y_train))
        self.y_pred = self.model.predict(self.x_test).argmax(axis=1)
        cm = confusion_matrix(self.y_test,self.y_pred)
        self.plot_confusion_matrix(cm,list(range(K)))
    
    def plot_confusion_matrix(self, cm, classes, normalize = False, title='Confusion matrix', cmap=plt.cm.Blues):
        if normalize:
            cm = cm.astype('float') / cm.sum(axis=1)[:,np.newaxis]
            print("Normalized confusion matrix")
        else:
            print("Confusion matrix, without normalization")
        print(cm)
        f3 = plt.figure(3)
        plt.imshow(cm, interpolation='nearest', cmap=cmap)
        plt.title(title)
        plt.colorbar()
        tick_marks = np.arange(len(classes))
        plt.xticks(tick_marks, classes, rotation=45)
        plt.yticks(tick_marks, classes)
        
        fmt = '.2f' if normalize else 'd' 
        thresh = cm.max()/2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            plt.text(j, i, format(cm[i, j], fmt),
                     horizontalalignment = "center",
                     color = "white" if cm[i, j] > thresh else "black")
            plt.tight_layout()
            plt.ylabel('True label')
            plt.xlabel('predicted label')
            f3.show()

# %%
model_name = "cnn" 
path='/kaggle/input/user1-all-h5/_hand.h5'
motion = models(path)
motion.read_h5()
model=motion.cnn_model_2()
motion.draw()
motion.con_matrix()

# %%
class models():
    def __init__(self, path):
        self.path = path
        
        
    def read_h5(self):
        f = h5py.File(path, 'r')
        X = f.get('inputs')
        y = f.get('labels') 
        
        X = np.array(X)
        y = np.array(y)
        self.x_train, self.x_test, self.y_train, self.y_test = train_test_split(X, y, test_size=0.2, random_state = 1)
        print(self.x_train.shape,self.y_train.shape)
    def draw(self):
        f1 = plt.figure(1)
        plt.title('Loss')
        plt.plot(self.r.history['loss'], label = 'loss')
        plt.plot(self.r.history['val_loss'], label = 'val_loss')
        plt.legend()
        f1.show()
        
        f2 = plt.figure(2)
        plt.plot(self.r.history['accuracy'], label = 'accuracy')
        plt.plot(self.r.history['val_accuracy'], label = 'val_accuracy')
        plt.legend()
        f2.show()    
#     def cnn_model(self):
#         K = len(set(self.y_train))
# #         print(K)
        
#         print(self.x_train.shape,self.y_train.shape)
# #         Input_shape should be a 4dim vectors as stated in the keras doc:
#         self.x_train = np.expand_dims(self.x_train, -1)
#         self.x_test = np.expand_dims(self.x_test,-1)
#         print(self.x_train.shape,self.y_train.shape)
        
#         i = Input(shape=self.x_train[0].shape)
#         print(self.x_train[0].shape)
#         x = Conv2D(16, (3,3), strides = 2, activation = 'relu',padding='same',kernel_regularizer=regularizers.l2(0.0005))(i)
#         x = BatchNormalization()(x)
#         x = Dropout(0.2)(x)
#         x = Flatten()(x)    
#         x = Dropout(0.2)(x)
#         x = Dense(128,activation = 'relu')(x)
#         x = BatchNormalization()(x)
#         x = Dropout(0.2)(x)
#         x = Dense(K, activation = 'softmax')(x)       
#         self.model = Model(i,x)
#         self.model.compile(optimizer = Adam(learning_rate=0.0005),
#               loss = 'sparse_categorical_crossentropy',
#               metrics = ['accuracy'])
        
#         self.r = self.model.fit(self.x_train, self.y_train, validation_data = (self.x_test, self.y_test), epochs = 200, batch_size = 128 )
#         print(self.model.summary())
#         return self.r
    
    def cnn_model_2(self):
        K = len(set(self.y_train))
#         print(K)
        
        print(self.x_train.shape,self.y_train.shape)
#         Input_shape should be a 4dim vectors as stated in the keras doc:
#         self.x_train = np.expand_dims(self.x_train, -1)
#         self.x_test = np.expand_dims(self.x_test,-1)
        print(self.x_train.shape,self.y_train.shape)
        
        i = Input(shape=self.x_train[0].shape)
        print(self.x_train[0].shape)
        x = Conv1D(32, 5, strides = 1, activation = 'relu',padding='same',kernel_regularizer=regularizers.l2(0.0005))(i)
        #x = BatchNormalization()(x)
        x = MaxPooling2D(pool_size=(1,2), strides=(1,2))
        #x = Dropout(0.2)(x)
        #x = Flatten()(x)    
        #x = Dropout(0.2)(x)
        x = Conv1D(64, 3, strides = 1, activation = 'relu',padding='same',kernel_regularizer=regularizers.l2(0.0005))(i)
        #x = BatchNormalization()(x)
        x = MaxPooling2D(pool_size=(1,2), strides=(1,2))
        #x = Dropout(0.2)(x)
        #x = Flatten()(x)  
        #x = Dropout(0.2)(x)
        x = Conv1D(128, 3, strides = 1, activation = 'relu',padding='same',kernel_regularizer=regularizers.l2(0.0005))(i)
#         x=layers.Reshape((500, 23), input_shape=x.shape)
        x = Bidirectional(layers.LSTM(64, return_sequences=True))(x)
        #x = Bidirectional(LSTM(64))(x)
        x = Flatten()(x)
        x = Dense(8, activation = 'softmax')(x)
        
        self.model = Model(i,x)
        self.model.compile(optimizer = Adam(learning_rate=0.0005),
              loss = 'sparse_categorical_crossentropy',
              metrics = ['accuracy'])
        
        self.r = self.model.fit(self.x_train, self.y_train, validation_data = (self.x_test, self.y_test), epochs = 200, batch_size = 128 )
        print(self.model.summary())
        return self.r
    
        
    def con_matrix(self):
        K = len(set(self.y_train))
        self.y_pred = self.model.predict(self.x_test).argmax(axis=1)
        cm = confusion_matrix(self.y_test,self.y_pred)
        self.plot_confusion_matrix(cm,list(range(K)))
    
    def plot_confusion_matrix(self, cm, classes, normalize = False, title='Confusion matrix', cmap=plt.cm.Blues):
        if normalize:
            cm = cm.astype('float') / cm.sum(axis=1)[:,np.newaxis]
            print("Normalized confusion matrix")
        else:
            print("Confusion matrix, without normalization")
        print(cm)
        f3 = plt.figure(3)
        plt.imshow(cm, interpolation='nearest', cmap=cmap)
        plt.title(title)
        plt.colorbar()
        tick_marks = np.arange(len(classes))
        plt.xticks(tick_marks, classes, rotation=45)
        plt.yticks(tick_marks, classes)
        
        fmt = '.2f' if normalize else 'd' 
        thresh = cm.max()/2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            plt.text(j, i, format(cm[i, j], fmt),
                     horizontalalignment = "center",
                     color = "white" if cm[i, j] > thresh else "black")
            plt.tight_layout()
            plt.ylabel('True label')
            plt.xlabel('predicted label')
            f3.show()

# %%
model_name = "cnn" 
path='/kaggle/input/user1-all-h5/_hips.h5'
motion = models(path)
motion.read_h5()
model=motion.cnn_model_2()
motion.draw()
motion.con_matrix()
# Out:
# (9716, 500, 22) (9716,)
# (9716, 500, 22) (9716,)
# (9716, 500, 22) (9716,)
# (500, 22)
# 2022-11-08 13:10:32.362133: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 13:10:32.363193: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 13:10:32.527506: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 13:10:32.528539: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 13:10:32.529412: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 13:10:32.530273: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 13:10:32.532999: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-08 13:10:32.795317: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 13:10:32.796228: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 13:10:32.796999: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 13:10:32.797735: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 13:10:32.798449: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 13:10:32.799233: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 13:10:36.121063: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 13:10:36.122042: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 13:10:36.122844: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 13:10:36.123605: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 13:10:36.124361: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 13:10:36.125084: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-11-08 13:10:36.128564: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-08 13:10:36.129299: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# 2022-11-08 13:10:37.982169: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 2022-11-08 13:10:41.753704: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 76/76 [==============================] - 18s 74ms/step - loss: 1.9586 - accuracy: 0.4582 - val_loss: 1.0881 - val_accuracy: 0.5663
# Epoch 2/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.8951 - accuracy: 0.6705 - val_loss: 0.8638 - val_accuracy: 0.7218
# Epoch 3/200
# 76/76 [==============================] - 5s 65ms/step - loss: 0.7064 - accuracy: 0.7405 - val_loss: 0.6077 - val_accuracy: 0.8053
# Epoch 4/200
# 76/76 [==============================] - 5s 61ms/step - loss: 0.6352 - accuracy: 0.7696 - val_loss: 0.5249 - val_accuracy: 0.8111
# Epoch 5/200
# 76/76 [==============================] - 4s 58ms/step - loss: 0.5480 - accuracy: 0.7944 - val_loss: 0.7705 - val_accuracy: 0.7185
# Epoch 6/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.6014 - accuracy: 0.7773 - val_loss: 0.5286 - val_accuracy: 0.8045
# Epoch 7/200
# 76/76 [==============================] - 5s 60ms/step - loss: 0.5878 - accuracy: 0.7946 - val_loss: 0.4872 - val_accuracy: 0.8259
# Epoch 8/200
# 76/76 [==============================] - 4s 58ms/step - loss: 0.5174 - accuracy: 0.8103 - val_loss: 0.4184 - val_accuracy: 0.8510
# Epoch 9/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.4698 - accuracy: 0.8267 - val_loss: 0.5644 - val_accuracy: 0.8103
# Epoch 10/200
# 76/76 [==============================] - 5s 66ms/step - loss: 0.5807 - accuracy: 0.7970 - val_loss: 0.6164 - val_accuracy: 0.7881
# Epoch 11/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.4524 - accuracy: 0.8328 - val_loss: 0.4707 - val_accuracy: 0.8321
# Epoch 12/200
# 76/76 [==============================] - 5s 60ms/step - loss: 0.4251 - accuracy: 0.8453 - val_loss: 0.4602 - val_accuracy: 0.8383
# Epoch 13/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.4256 - accuracy: 0.8477 - val_loss: 0.5049 - val_accuracy: 0.8218
# Epoch 14/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.4433 - accuracy: 0.8390 - val_loss: 0.4670 - val_accuracy: 0.8403
# Epoch 15/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.4189 - accuracy: 0.8457 - val_loss: 0.4182 - val_accuracy: 0.8473
# Epoch 16/200
# 76/76 [==============================] - 5s 65ms/step - loss: 0.3701 - accuracy: 0.8668 - val_loss: 0.3988 - val_accuracy: 0.8547
# Epoch 17/200
# 76/76 [==============================] - 5s 63ms/step - loss: 0.3538 - accuracy: 0.8706 - val_loss: 0.3399 - val_accuracy: 0.8844
# Epoch 18/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.5473 - accuracy: 0.8235 - val_loss: 0.5310 - val_accuracy: 0.7971
# Epoch 19/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.5114 - accuracy: 0.8191 - val_loss: 0.4490 - val_accuracy: 0.8428
# Epoch 20/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.4468 - accuracy: 0.8364 - val_loss: 0.6918 - val_accuracy: 0.7905
# Epoch 21/200
# 76/76 [==============================] - 5s 64ms/step - loss: 0.3758 - accuracy: 0.8630 - val_loss: 0.3686 - val_accuracy: 0.8786
# Epoch 22/200
# 76/76 [==============================] - 5s 60ms/step - loss: 0.3645 - accuracy: 0.8707 - val_loss: 0.4259 - val_accuracy: 0.8593
# Epoch 23/200
# 76/76 [==============================] - 5s 69ms/step - loss: 0.4152 - accuracy: 0.8538 - val_loss: 0.5309 - val_accuracy: 0.8107
# Epoch 24/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.4083 - accuracy: 0.8564 - val_loss: 0.4836 - val_accuracy: 0.8473
# Epoch 25/200
# 76/76 [==============================] - 5s 63ms/step - loss: 0.5368 - accuracy: 0.8304 - val_loss: 0.4971 - val_accuracy: 0.8251
# Epoch 26/200
# 76/76 [==============================] - 5s 60ms/step - loss: 0.4705 - accuracy: 0.8401 - val_loss: 0.4252 - val_accuracy: 0.8630
# Epoch 27/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.4373 - accuracy: 0.8465 - val_loss: 0.4154 - val_accuracy: 0.8704
# Epoch 28/200
# 76/76 [==============================] - 5s 63ms/step - loss: 0.3911 - accuracy: 0.8656 - val_loss: 0.3305 - val_accuracy: 0.9008
# Epoch 29/200
# 76/76 [==============================] - 4s 58ms/step - loss: 0.3542 - accuracy: 0.8808 - val_loss: 0.3853 - val_accuracy: 0.8716
# Epoch 30/200
# 76/76 [==============================] - 5s 71ms/step - loss: 0.3568 - accuracy: 0.8795 - val_loss: 0.3360 - val_accuracy: 0.8885
# Epoch 31/200
# 76/76 [==============================] - 4s 58ms/step - loss: 0.3417 - accuracy: 0.8819 - val_loss: 0.3933 - val_accuracy: 0.8691
# Epoch 32/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.3459 - accuracy: 0.8803 - val_loss: 0.3916 - val_accuracy: 0.8671
# Epoch 33/200
# 76/76 [==============================] - 4s 58ms/step - loss: 0.3294 - accuracy: 0.8877 - val_loss: 0.3830 - val_accuracy: 0.8716
# Epoch 34/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.3478 - accuracy: 0.8853 - val_loss: 0.4576 - val_accuracy: 0.8551
# Epoch 35/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.3825 - accuracy: 0.8723 - val_loss: 0.5472 - val_accuracy: 0.8424
# Epoch 36/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.3460 - accuracy: 0.8831 - val_loss: 0.4114 - val_accuracy: 0.8630
# Epoch 37/200
# 76/76 [==============================] - 5s 70ms/step - loss: 0.3527 - accuracy: 0.8823 - val_loss: 0.4699 - val_accuracy: 0.8305
# Epoch 38/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.3609 - accuracy: 0.8795 - val_loss: 0.4345 - val_accuracy: 0.8560
# Epoch 39/200
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3692 - accuracy: 0.8772 - val_loss: 0.4504 - val_accuracy: 0.8675
# Epoch 40/200
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3390 - accuracy: 0.8881 - val_loss: 0.3874 - val_accuracy: 0.8786
# Epoch 41/200
# 76/76 [==============================] - 5s 60ms/step - loss: 0.3162 - accuracy: 0.8927 - val_loss: 0.3903 - val_accuracy: 0.8733
# Epoch 42/200
# 76/76 [==============================] - 5s 63ms/step - loss: 0.3557 - accuracy: 0.8797 - val_loss: 0.4217 - val_accuracy: 0.8576
# Epoch 43/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.3734 - accuracy: 0.8789 - val_loss: 0.3146 - val_accuracy: 0.8992
# Epoch 44/200
# 76/76 [==============================] - 6s 73ms/step - loss: 0.3296 - accuracy: 0.8882 - val_loss: 0.3327 - val_accuracy: 0.8922
# Epoch 45/200
# 76/76 [==============================] - 5s 60ms/step - loss: 0.3342 - accuracy: 0.8905 - val_loss: 0.3302 - val_accuracy: 0.8963
# Epoch 46/200
# 76/76 [==============================] - 5s 60ms/step - loss: 0.3176 - accuracy: 0.8951 - val_loss: 0.3433 - val_accuracy: 0.8918
# Epoch 47/200
# 76/76 [==============================] - 5s 60ms/step - loss: 0.3589 - accuracy: 0.8831 - val_loss: 0.3902 - val_accuracy: 0.8893
# Epoch 48/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.3080 - accuracy: 0.8978 - val_loss: 0.3250 - val_accuracy: 0.8909
# Epoch 49/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.6153 - accuracy: 0.8315 - val_loss: 0.5418 - val_accuracy: 0.8362
# Epoch 50/200
# 76/76 [==============================] - 5s 66ms/step - loss: 0.3860 - accuracy: 0.8796 - val_loss: 0.2978 - val_accuracy: 0.9091
# Epoch 51/200
# 76/76 [==============================] - 5s 63ms/step - loss: 0.2911 - accuracy: 0.9003 - val_loss: 0.4385 - val_accuracy: 0.8671
# Epoch 52/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.3295 - accuracy: 0.8897 - val_loss: 0.3467 - val_accuracy: 0.8967
# Epoch 53/200
# 76/76 [==============================] - 4s 58ms/step - loss: 0.2670 - accuracy: 0.9120 - val_loss: 0.3504 - val_accuracy: 0.8947
# Epoch 54/200
# 76/76 [==============================] - 5s 63ms/step - loss: 0.3340 - accuracy: 0.8946 - val_loss: 0.3553 - val_accuracy: 0.8885
# Epoch 55/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.3094 - accuracy: 0.9022 - val_loss: 0.4104 - val_accuracy: 0.8782
# Epoch 56/200
# 76/76 [==============================] - 5s 63ms/step - loss: 0.3084 - accuracy: 0.8978 - val_loss: 0.4873 - val_accuracy: 0.8687
# Epoch 57/200
# 76/76 [==============================] - 5s 66ms/step - loss: 0.3106 - accuracy: 0.8984 - val_loss: 0.3466 - val_accuracy: 0.8922
# Epoch 58/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.3051 - accuracy: 0.9014 - val_loss: 1.3413 - val_accuracy: 0.8177
# Epoch 59/200
# 76/76 [==============================] - 4s 58ms/step - loss: 0.6756 - accuracy: 0.8173 - val_loss: 0.5475 - val_accuracy: 0.8342
# Epoch 60/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.3678 - accuracy: 0.8795 - val_loss: 0.3284 - val_accuracy: 0.8988
# Epoch 61/200
# 76/76 [==============================] - 5s 63ms/step - loss: 0.3024 - accuracy: 0.9002 - val_loss: 0.3606 - val_accuracy: 0.8864
# Epoch 62/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2860 - accuracy: 0.9047 - val_loss: 0.3298 - val_accuracy: 0.8963
# Epoch 63/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.3186 - accuracy: 0.8936 - val_loss: 0.3163 - val_accuracy: 0.9045
# Epoch 64/200
# 76/76 [==============================] - 5s 66ms/step - loss: 0.3081 - accuracy: 0.8964 - val_loss: 0.4348 - val_accuracy: 0.8761
# Epoch 65/200
# 76/76 [==============================] - 5s 63ms/step - loss: 0.2900 - accuracy: 0.9054 - val_loss: 0.3486 - val_accuracy: 0.8889
# Epoch 66/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2536 - accuracy: 0.9222 - val_loss: 0.2972 - val_accuracy: 0.9119
# Epoch 67/200
# 76/76 [==============================] - 5s 60ms/step - loss: 0.2861 - accuracy: 0.9025 - val_loss: 0.4824 - val_accuracy: 0.8765
# Epoch 68/200
# 76/76 [==============================] - 5s 63ms/step - loss: 0.3444 - accuracy: 0.8905 - val_loss: 0.4560 - val_accuracy: 0.8757
# Epoch 69/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2927 - accuracy: 0.9048 - val_loss: 0.3358 - val_accuracy: 0.8881
# Epoch 70/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.2642 - accuracy: 0.9159 - val_loss: 0.3258 - val_accuracy: 0.9008
# Epoch 71/200
# 76/76 [==============================] - 5s 65ms/step - loss: 0.3098 - accuracy: 0.8998 - val_loss: 0.3401 - val_accuracy: 0.8951
# Epoch 72/200
# 76/76 [==============================] - 5s 63ms/step - loss: 0.2509 - accuracy: 0.9158 - val_loss: 0.3226 - val_accuracy: 0.8988
# Epoch 73/200
# 76/76 [==============================] - 5s 60ms/step - loss: 0.2831 - accuracy: 0.9092 - val_loss: 0.5613 - val_accuracy: 0.8535
# Epoch 74/200
# 76/76 [==============================] - 5s 60ms/step - loss: 0.2919 - accuracy: 0.9093 - val_loss: 0.3659 - val_accuracy: 0.8934
# Epoch 75/200
# 76/76 [==============================] - 5s 63ms/step - loss: 0.2913 - accuracy: 0.9080 - val_loss: 0.3214 - val_accuracy: 0.9066
# Epoch 76/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2674 - accuracy: 0.9144 - val_loss: 0.4428 - val_accuracy: 0.8535
# Epoch 77/200
# 76/76 [==============================] - 5s 70ms/step - loss: 0.3595 - accuracy: 0.8879 - val_loss: 0.4376 - val_accuracy: 0.8790
# Epoch 78/200
# 76/76 [==============================] - 5s 59ms/step - loss: 0.3553 - accuracy: 0.8883 - val_loss: 0.3943 - val_accuracy: 0.8844
# Epoch 79/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.3080 - accuracy: 0.9059 - val_loss: 0.3742 - val_accuracy: 0.8848
# Epoch 80/200
# 76/76 [==============================] - 5s 59ms/step - loss: 0.2764 - accuracy: 0.9086 - val_loss: 0.3487 - val_accuracy: 0.9029
# Epoch 81/200
# 76/76 [==============================] - 5s 59ms/step - loss: 0.3037 - accuracy: 0.9028 - val_loss: 0.3182 - val_accuracy: 0.9144
# Epoch 82/200
# 76/76 [==============================] - 5s 63ms/step - loss: 0.3070 - accuracy: 0.9070 - val_loss: 2.6019 - val_accuracy: 0.6646
# Epoch 83/200
# 76/76 [==============================] - 5s 59ms/step - loss: 0.5818 - accuracy: 0.8535 - val_loss: 0.3503 - val_accuracy: 0.8959
# Epoch 84/200
# 76/76 [==============================] - 5s 71ms/step - loss: 0.3200 - accuracy: 0.8963 - val_loss: 0.4071 - val_accuracy: 0.8901
# Epoch 85/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2963 - accuracy: 0.9082 - val_loss: 0.3491 - val_accuracy: 0.8955
# Epoch 86/200
# 76/76 [==============================] - 5s 61ms/step - loss: 0.2571 - accuracy: 0.9182 - val_loss: 0.2794 - val_accuracy: 0.9202
# Epoch 87/200
# 76/76 [==============================] - 5s 59ms/step - loss: 0.2674 - accuracy: 0.9159 - val_loss: 0.2939 - val_accuracy: 0.9140
# Epoch 88/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2595 - accuracy: 0.9132 - val_loss: 0.3520 - val_accuracy: 0.8959
# Epoch 89/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.2653 - accuracy: 0.9180 - val_loss: 0.5685 - val_accuracy: 0.8432
# Epoch 90/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2820 - accuracy: 0.9134 - val_loss: 0.3762 - val_accuracy: 0.8959
# Epoch 91/200
# 76/76 [==============================] - 5s 69ms/step - loss: 0.2980 - accuracy: 0.9055 - val_loss: 0.3482 - val_accuracy: 0.9008
# Epoch 92/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2691 - accuracy: 0.9134 - val_loss: 0.4100 - val_accuracy: 0.8877
# Epoch 93/200
# 76/76 [==============================] - 4s 58ms/step - loss: 0.2787 - accuracy: 0.9104 - val_loss: 0.4448 - val_accuracy: 0.8584
# Epoch 94/200
# 76/76 [==============================] - 5s 63ms/step - loss: 0.3502 - accuracy: 0.8916 - val_loss: 0.4180 - val_accuracy: 0.8700
# Epoch 95/200
# 76/76 [==============================] - 4s 58ms/step - loss: 0.3433 - accuracy: 0.8895 - val_loss: 0.3772 - val_accuracy: 0.8782
# Epoch 96/200
# 76/76 [==============================] - 5s 63ms/step - loss: 0.2713 - accuracy: 0.9139 - val_loss: 0.2979 - val_accuracy: 0.9086
# Epoch 97/200
# 76/76 [==============================] - 4s 58ms/step - loss: 0.2764 - accuracy: 0.9113 - val_loss: 0.4708 - val_accuracy: 0.8716
# Epoch 98/200
# 76/76 [==============================] - 5s 69ms/step - loss: 0.2631 - accuracy: 0.9188 - val_loss: 0.3212 - val_accuracy: 0.9041
# Epoch 99/200
# 76/76 [==============================] - 4s 58ms/step - loss: 0.3023 - accuracy: 0.9040 - val_loss: 0.3508 - val_accuracy: 0.9033
# Epoch 100/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2592 - accuracy: 0.9192 - val_loss: 0.3636 - val_accuracy: 0.9004
# Epoch 101/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.2683 - accuracy: 0.9227 - val_loss: 0.4246 - val_accuracy: 0.8844
# Epoch 102/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.3797 - accuracy: 0.8894 - val_loss: 0.3899 - val_accuracy: 0.8938
# Epoch 103/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.2698 - accuracy: 0.9177 - val_loss: 0.4582 - val_accuracy: 0.8860
# Epoch 104/200
# 76/76 [==============================] - 5s 70ms/step - loss: 0.2481 - accuracy: 0.9203 - val_loss: 0.3772 - val_accuracy: 0.8930
# Epoch 105/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.2655 - accuracy: 0.9169 - val_loss: 0.3160 - val_accuracy: 0.9222
# Epoch 106/200
# 76/76 [==============================] - 4s 58ms/step - loss: 0.2467 - accuracy: 0.9210 - val_loss: 0.3510 - val_accuracy: 0.8881
# Epoch 107/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2565 - accuracy: 0.9177 - val_loss: 0.3706 - val_accuracy: 0.8852
# Epoch 108/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.2892 - accuracy: 0.9110 - val_loss: 0.2980 - val_accuracy: 0.9152
# Epoch 109/200
# 76/76 [==============================] - 4s 58ms/step - loss: 0.2544 - accuracy: 0.9202 - val_loss: 0.5271 - val_accuracy: 0.8514
# Epoch 110/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.2846 - accuracy: 0.9140 - val_loss: 0.3864 - val_accuracy: 0.8909
# Epoch 111/200
# 76/76 [==============================] - 5s 65ms/step - loss: 0.3379 - accuracy: 0.8944 - val_loss: 0.4025 - val_accuracy: 0.8909
# Epoch 112/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.7264 - accuracy: 0.8341 - val_loss: 0.4645 - val_accuracy: 0.8597
# Epoch 113/200
# 76/76 [==============================] - 5s 59ms/step - loss: 0.3274 - accuracy: 0.8974 - val_loss: 0.4405 - val_accuracy: 0.8658
# Epoch 114/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2716 - accuracy: 0.9141 - val_loss: 0.3453 - val_accuracy: 0.9070
# Epoch 115/200
# 76/76 [==============================] - 5s 63ms/step - loss: 0.2426 - accuracy: 0.9245 - val_loss: 0.2981 - val_accuracy: 0.9193
# Epoch 116/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2361 - accuracy: 0.9250 - val_loss: 0.3163 - val_accuracy: 0.9156
# Epoch 117/200
# 76/76 [==============================] - 5s 63ms/step - loss: 0.2315 - accuracy: 0.9260 - val_loss: 0.3024 - val_accuracy: 0.9144
# Epoch 118/200
# 76/76 [==============================] - 5s 66ms/step - loss: 0.3089 - accuracy: 0.9052 - val_loss: 0.3491 - val_accuracy: 0.9041
# Epoch 119/200
# 76/76 [==============================] - 5s 60ms/step - loss: 0.2434 - accuracy: 0.9238 - val_loss: 0.3104 - val_accuracy: 0.9140
# Epoch 120/200
# 76/76 [==============================] - 5s 61ms/step - loss: 0.2631 - accuracy: 0.9206 - val_loss: 0.4028 - val_accuracy: 0.8947
# Epoch 121/200
# 76/76 [==============================] - 4s 58ms/step - loss: 0.2934 - accuracy: 0.9087 - val_loss: 0.4034 - val_accuracy: 0.8798
# Epoch 122/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.2474 - accuracy: 0.9222 - val_loss: 0.3548 - val_accuracy: 0.9099
# Epoch 123/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2294 - accuracy: 0.9276 - val_loss: 0.3139 - val_accuracy: 0.9095
# Epoch 124/200
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3191 - accuracy: 0.9014 - val_loss: 0.4417 - val_accuracy: 0.8802
# Epoch 125/200
# 76/76 [==============================] - 5s 66ms/step - loss: 0.2859 - accuracy: 0.9124 - val_loss: 0.3561 - val_accuracy: 0.9058
# Epoch 126/200
# 76/76 [==============================] - 5s 59ms/step - loss: 0.2266 - accuracy: 0.9294 - val_loss: 0.3718 - val_accuracy: 0.9107
# Epoch 127/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.2339 - accuracy: 0.9265 - val_loss: 0.4042 - val_accuracy: 0.8770
# Epoch 128/200
# 76/76 [==============================] - 4s 58ms/step - loss: 0.2498 - accuracy: 0.9202 - val_loss: 0.2993 - val_accuracy: 0.9144
# Epoch 129/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.2469 - accuracy: 0.9201 - val_loss: 0.3013 - val_accuracy: 0.9288
# Epoch 130/200
# 76/76 [==============================] - 4s 58ms/step - loss: 0.2643 - accuracy: 0.9194 - val_loss: 0.3875 - val_accuracy: 0.8988
# Epoch 131/200
# 76/76 [==============================] - 5s 66ms/step - loss: 0.2675 - accuracy: 0.9146 - val_loss: 0.3336 - val_accuracy: 0.9062
# Epoch 132/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.2803 - accuracy: 0.9131 - val_loss: 0.4038 - val_accuracy: 0.9004
# Epoch 133/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.3546 - accuracy: 0.8967 - val_loss: 0.3283 - val_accuracy: 0.9066
# Epoch 134/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.2346 - accuracy: 0.9257 - val_loss: 0.2947 - val_accuracy: 0.9206
# Epoch 135/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2120 - accuracy: 0.9334 - val_loss: 0.3314 - val_accuracy: 0.9082
# Epoch 136/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.2968 - accuracy: 0.9100 - val_loss: 0.6865 - val_accuracy: 0.8317
# Epoch 137/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2416 - accuracy: 0.9282 - val_loss: 0.3795 - val_accuracy: 0.8984
# Epoch 138/200
# 76/76 [==============================] - 5s 69ms/step - loss: 0.2473 - accuracy: 0.9191 - val_loss: 0.3203 - val_accuracy: 0.9123
# Epoch 139/200
# 76/76 [==============================] - 5s 60ms/step - loss: 0.3357 - accuracy: 0.9036 - val_loss: 0.4529 - val_accuracy: 0.8115
# Epoch 140/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.4764 - accuracy: 0.8572 - val_loss: 0.3822 - val_accuracy: 0.8951
# Epoch 141/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.3276 - accuracy: 0.8915 - val_loss: 0.3836 - val_accuracy: 0.8720
# Epoch 142/200
# 76/76 [==============================] - 5s 59ms/step - loss: 0.3452 - accuracy: 0.8898 - val_loss: 0.3732 - val_accuracy: 0.9016
# Epoch 143/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.3523 - accuracy: 0.8917 - val_loss: 0.4186 - val_accuracy: 0.8864
# Epoch 144/200
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3775 - accuracy: 0.8893 - val_loss: 0.3944 - val_accuracy: 0.9000
# Epoch 145/200
# 76/76 [==============================] - 5s 69ms/step - loss: 0.3233 - accuracy: 0.8978 - val_loss: 0.3450 - val_accuracy: 0.8918
# Epoch 146/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.3158 - accuracy: 0.8980 - val_loss: 0.3454 - val_accuracy: 0.8975
# Epoch 147/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.3027 - accuracy: 0.8978 - val_loss: 0.3847 - val_accuracy: 0.8901
# Epoch 148/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.2916 - accuracy: 0.9074 - val_loss: 0.4291 - val_accuracy: 0.8831
# Epoch 149/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2851 - accuracy: 0.9090 - val_loss: 0.3856 - val_accuracy: 0.8988
# Epoch 150/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.3272 - accuracy: 0.9012 - val_loss: 0.4607 - val_accuracy: 0.8823
# Epoch 151/200
# 76/76 [==============================] - 4s 58ms/step - loss: 0.3264 - accuracy: 0.8959 - val_loss: 0.4429 - val_accuracy: 0.8770
# Epoch 152/200
# 76/76 [==============================] - 5s 66ms/step - loss: 0.2667 - accuracy: 0.9145 - val_loss: 0.3594 - val_accuracy: 0.8988
# Epoch 153/200
# 76/76 [==============================] - 5s 60ms/step - loss: 0.2560 - accuracy: 0.9174 - val_loss: 0.4092 - val_accuracy: 0.8741
# Epoch 154/200
# 76/76 [==============================] - 4s 58ms/step - loss: 0.2769 - accuracy: 0.9043 - val_loss: 0.3620 - val_accuracy: 0.9078
# Epoch 155/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.2637 - accuracy: 0.9182 - val_loss: 0.4433 - val_accuracy: 0.8905
# Epoch 156/200
# 76/76 [==============================] - 4s 58ms/step - loss: 0.2888 - accuracy: 0.9046 - val_loss: 0.4158 - val_accuracy: 0.8765
# Epoch 157/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.2768 - accuracy: 0.9090 - val_loss: 0.3878 - val_accuracy: 0.8942
# Epoch 158/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2764 - accuracy: 0.9097 - val_loss: 0.3555 - val_accuracy: 0.8988
# Epoch 159/200
# 76/76 [==============================] - 5s 66ms/step - loss: 0.2795 - accuracy: 0.9103 - val_loss: 0.3292 - val_accuracy: 0.9033
# Epoch 160/200
# 76/76 [==============================] - 5s 63ms/step - loss: 0.2583 - accuracy: 0.9197 - val_loss: 0.3442 - val_accuracy: 0.9091
# Epoch 161/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.4672 - accuracy: 0.8735 - val_loss: 0.4575 - val_accuracy: 0.8790
# Epoch 162/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.3418 - accuracy: 0.8988 - val_loss: 0.4202 - val_accuracy: 0.8922
# Epoch 163/200
# 76/76 [==============================] - 4s 58ms/step - loss: 0.2447 - accuracy: 0.9262 - val_loss: 0.3520 - val_accuracy: 0.9078
# Epoch 164/200
# 76/76 [==============================] - 5s 61ms/step - loss: 0.2484 - accuracy: 0.9261 - val_loss: 0.4672 - val_accuracy: 0.8765
# Epoch 165/200
# 76/76 [==============================] - 5s 67ms/step - loss: 0.2120 - accuracy: 0.9368 - val_loss: 0.2935 - val_accuracy: 0.9247
# Epoch 166/200
# 76/76 [==============================] - 5s 60ms/step - loss: 0.3066 - accuracy: 0.9057 - val_loss: 0.4099 - val_accuracy: 0.9004
# Epoch 167/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.2686 - accuracy: 0.9195 - val_loss: 0.4013 - val_accuracy: 0.9012
# Epoch 168/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2129 - accuracy: 0.9353 - val_loss: 0.3009 - val_accuracy: 0.9243
# Epoch 169/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.1979 - accuracy: 0.9429 - val_loss: 0.3447 - val_accuracy: 0.9029
# Epoch 170/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2367 - accuracy: 0.9301 - val_loss: 0.3420 - val_accuracy: 0.9078
# Epoch 171/200
# 76/76 [==============================] - 5s 60ms/step - loss: 0.2161 - accuracy: 0.9358 - val_loss: 0.3707 - val_accuracy: 0.9037
# Epoch 172/200
# 76/76 [==============================] - 5s 69ms/step - loss: 0.2161 - accuracy: 0.9359 - val_loss: 0.4017 - val_accuracy: 0.9111
# Epoch 173/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2891 - accuracy: 0.9193 - val_loss: 0.4129 - val_accuracy: 0.8971
# Epoch 174/200
# 76/76 [==============================] - 5s 61ms/step - loss: 0.2734 - accuracy: 0.9195 - val_loss: 0.3825 - val_accuracy: 0.9058
# Epoch 175/200
# 76/76 [==============================] - 4s 58ms/step - loss: 0.2195 - accuracy: 0.9372 - val_loss: 0.4621 - val_accuracy: 0.8835
# Epoch 176/200
# 76/76 [==============================] - 5s 61ms/step - loss: 0.3012 - accuracy: 0.9180 - val_loss: 0.4608 - val_accuracy: 0.8947
# Epoch 177/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2526 - accuracy: 0.9253 - val_loss: 0.5450 - val_accuracy: 0.8663
# Epoch 178/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2742 - accuracy: 0.9203 - val_loss: 0.3075 - val_accuracy: 0.9226
# Epoch 179/200
# 76/76 [==============================] - 5s 69ms/step - loss: 0.2064 - accuracy: 0.9383 - val_loss: 0.3710 - val_accuracy: 0.9210
# Epoch 180/200
# 76/76 [==============================] - 4s 58ms/step - loss: 0.2368 - accuracy: 0.9311 - val_loss: 0.3180 - val_accuracy: 0.9202
# Epoch 181/200
# 76/76 [==============================] - 5s 63ms/step - loss: 0.2542 - accuracy: 0.9266 - val_loss: 0.3960 - val_accuracy: 0.8947
# Epoch 182/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2131 - accuracy: 0.9389 - val_loss: 0.3073 - val_accuracy: 0.9239
# Epoch 183/200
# 76/76 [==============================] - 5s 63ms/step - loss: 0.1906 - accuracy: 0.9439 - val_loss: 0.3901 - val_accuracy: 0.9029
# Epoch 184/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2213 - accuracy: 0.9330 - val_loss: 0.3419 - val_accuracy: 0.9181
# Epoch 185/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2428 - accuracy: 0.9299 - val_loss: 0.3484 - val_accuracy: 0.9177
# Epoch 186/200
# 76/76 [==============================] - 5s 70ms/step - loss: 0.2347 - accuracy: 0.9301 - val_loss: 0.3808 - val_accuracy: 0.9016
# Epoch 187/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2061 - accuracy: 0.9414 - val_loss: 0.3115 - val_accuracy: 0.9226
# Epoch 188/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.2133 - accuracy: 0.9357 - val_loss: 0.4418 - val_accuracy: 0.8914
# Epoch 189/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2556 - accuracy: 0.9277 - val_loss: 0.3346 - val_accuracy: 0.9230
# Epoch 190/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.2217 - accuracy: 0.9359 - val_loss: 0.3156 - val_accuracy: 0.9267
# Epoch 191/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2518 - accuracy: 0.9300 - val_loss: 0.3733 - val_accuracy: 0.9000
# Epoch 192/200
# 76/76 [==============================] - 5s 60ms/step - loss: 0.2011 - accuracy: 0.9394 - val_loss: 0.3085 - val_accuracy: 0.9267
# Epoch 193/200
# 76/76 [==============================] - 5s 69ms/step - loss: 0.1883 - accuracy: 0.9453 - val_loss: 0.3463 - val_accuracy: 0.9185
# Epoch 194/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2213 - accuracy: 0.9330 - val_loss: 0.3809 - val_accuracy: 0.9066
# Epoch 195/200
# 76/76 [==============================] - 5s 62ms/step - loss: 0.2261 - accuracy: 0.9339 - val_loss: 0.3972 - val_accuracy: 0.8955
# Epoch 196/200
# 76/76 [==============================] - 4s 59ms/step - loss: 0.2457 - accuracy: 0.9272 - val_loss: 0.3353 - val_accuracy: 0.9148
# Epoch 197/200
# 76/76 [==============================] - 5s 61ms/step - loss: 0.2172 - accuracy: 0.9371 - val_loss: 0.3531 - val_accuracy: 0.9074
# Epoch 198/200
# 76/76 [==============================] - 5s 60ms/step - loss: 0.2310 - accuracy: 0.9354 - val_loss: 0.5966 - val_accuracy: 0.8646
# Epoch 199/200
# 76/76 [==============================] - 5s 66ms/step - loss: 0.4032 - accuracy: 0.9013 - val_loss: 0.3285 - val_accuracy: 0.9226
# Epoch 200/200
# 76/76 [==============================] - 5s 63ms/step - loss: 0.2322 - accuracy: 0.9359 - val_loss: 0.3270 - val_accuracy: 0.9243
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 500, 22)]         0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 500, 128)          8576
# _________________________________________________________________
# bidirectional (Bidirectional (None, 500, 128)          98816
# _________________________________________________________________
# flatten (Flatten)            (None, 64000)             0
# _________________________________________________________________
# dense (Dense)                (None, 8)                 512008
# =================================================================
# Total params: 619,400
# Trainable params: 619,400
# Non-trainable params: 0
# _________________________________________________________________
# None
# Confusion matrix, without normalization
# [[334   4   0   0   0   0   0  34]
#  [  7 301   0   0   0   0   7   0]
#  [  4   2 293   0   0   0   3   1]
#  [  0   0   2  41   0   0   0   0]
#  [ 11  13   8   0 165   0   6   5]
#  [  0   0   0   0   0 425   2   0]
#  [  0  12   3   0   4   4 390   0]
#  [ 47   3   0   0   2   0   0 297]]
